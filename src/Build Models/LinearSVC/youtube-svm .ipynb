# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-31-25-109_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-06-14-938_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-18-20-122_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-03-55-015_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-55-12-414_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-19-04-118_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-43-04-568_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-34-40-006_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-26-01-401_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-19-04-118_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-31-25-109_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-09-16-859_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-00-57-806_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-31-53-016_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-03-55-015_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-55-12-414_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-58-16-162_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-31-53-016_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-45-50-026_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-34-40-006_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-26-01-401_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-58-16-162_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_08-03-30-047_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-00-57-806_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-06-14-938_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-18-20-122_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_08-03-30-047_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-45-50-026_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-43-04-568_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-09-16-859_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-22-11-101_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-00-39-309_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_07-06-09-265_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-09-41-839_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-14-17-851_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-17-18-999_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-14-06-748_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-02-52-651_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-41-37-486_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-46-06-402_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-12-41-330_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-13-02-577_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-00-40-626_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-46-06-402_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_07-06-09-265_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-12-41-330_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-47-16-542_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-09-41-839_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-00-40-626_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-49-32-259_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-04-34-437_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-07-18-602_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637 (1)_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-22-11-101_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-17-18-999_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-47-16-542_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-42-43-199_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-36-33-457_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-36-33-457_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-07-18-602_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-04-34-437_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-37-52-679_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-04-35-896_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-39-26-660_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-35-59-847_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-06-16-575_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-09-07-823_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-06-16-575_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-13-02-577_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-41-37-486_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-14-17-851_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-17-30-937_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-35-59-847_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-37-52-679_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637 (1)_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-25-24-979_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-28-43-748_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-28-43-748_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-25-24-979_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-09-07-823_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-04-35-896_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-39-26-660_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_05-58-34-900_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-27-34-645_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-49-32-259_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-14-06-748_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-00-39-309_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-02-52-651_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-27-34-645_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-17-30-937_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_05-58-34-900_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-42-43-199_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 23_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 17_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 15_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 20_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 22_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 19_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 24_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 21_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 18_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 23_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 17_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 19_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 20_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 15_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 16_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 14_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 13_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 24_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 20_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 13_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 25_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 17_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 20_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 16_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 19_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 22_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 23_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 14_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 23_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 17_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 15_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 15_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 19_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 25_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 18_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 21_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 17_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 3_textready_cleaned.xlsx
# ...
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/13_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/معرض الوحي_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/معرض الوحي_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/مكة مول_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/مكة مول_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/معرض الوحي_textready.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/ابراج الساعة_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/ابراج الساعة_textready.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/ابراج الساعة_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/مكة مول_textready.xlsx

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
import joblib

# %%
import os
import pandas as pd
from pathlib import Path

DATA_ROOT = "/kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing"

def read_csv_robust(path):
    encodings = ["utf-8", "utf-8-sig", "cp1256", "latin1"]
    for enc in encodings:
        try:
            return pd.read_csv(path, encoding=enc)
        except:
            pass
    return pd.read_csv(path, encoding="latin1", engine="python", on_bad_lines="skip")

def read_excel_robust(path):
    return pd.read_excel(path)

analysis_files = []

for root, _, files in os.walk(DATA_ROOT):
    for file in files:
        name_without_ext = os.path.splitext(file.lower())[0]
        if name_without_ext.endswith("analysis"):
            analysis_files.append(os.path.join(root, file))

print("Analysis files found:", len(analysis_files))
for f in analysis_files:
    print(f)
# Out:
# Analysis files found: 198
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-31-25-109_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-19-04-118_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-26-01-401_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-00-57-806_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-31-53-016_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-03-55-015_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-55-12-414_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-58-16-162_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-34-40-006_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_08-03-30-047_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-06-14-938_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-18-20-122_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-45-50-026_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-43-04-568_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-09-16-859_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-00-39-309_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-09-41-839_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-17-18-999_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-14-06-748_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-46-06-402_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-12-41-330_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-00-40-626_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_07-06-09-265_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-47-16-542_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-49-32-259_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-07-18-602_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-22-11-101_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-36-33-457_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-04-34-437_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-04-35-896_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-35-59-847_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-06-16-575_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-13-02-577_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-41-37-486_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-14-17-851_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-17-30-937_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-37-52-679_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637 (1)_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-25-24-979_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-28-43-748_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-09-07-823_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-39-26-660_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_05-58-34-900_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-02-52-651_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-27-34-645_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-42-43-199_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 23_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 15_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 20_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 19_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 17_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 20_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 23_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 17_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 15_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 19_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 25_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 25_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 19_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 17_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 15_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 23_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 20_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/تبوك/وادي الديسة_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/تبوك/تبوك_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/تبوك/جبل اللوز_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/تبوك/منطقة بجدة البرية_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/تبوك/تبوك1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/حائل/حائل3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/حائل/حائل_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/حائل/حائل2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/حائل/حائل4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/حائل/حائل1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/العلا4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/جبل الفيل_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/العلا5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/مسرح المرايا_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/مسرح المرايا2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/قرية العلا التراثية_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/العلا_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/العلا3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/المتحف المفتوح_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشمالية/( المنطقة الشمالية ) Youtube Data -  After Preproccesing/العلا/العلا2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/معرض الوحي_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/مكة مول_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/all-data-set/All Datasets For GP/YouTube Datasets - After Processing/المنطقة الغربية/مكة/ابراج الساعة_textready_analysis.xlsx

# %%
TEXT_PRIORITY = [
    "Text_ML",
    "Text_Cleaned",
    "Text_Normalized",
    "Text_TR",
    "Text_Base",
    "Text",
    "text",
    "Text_Orig"
]

LABEL_PRIORITY = [
    "Sentiment",
    "sentiment",
    "Label",
    "label"
]

def pick_first_existing(columns, priority_list):
    cols = set(columns)
    for c in priority_list:
        if c in cols:
            return c
    return None

dfs = []
failed = []

for path in analysis_files:
    try:
        ext = Path(path).suffix.lower()

        if ext == ".csv":
            df = read_csv_robust(path)
        elif ext in [".xlsx", ".xls"]:
            df = read_excel_robust(path)
        else:
            continue

        text_col = pick_first_existing(df.columns, TEXT_PRIORITY)
        label_col = pick_first_existing(df.columns, LABEL_PRIORITY)

        if text_col is None:
            print("No text column found:", path)
            continue

        out = pd.DataFrame()
        out["text"] = df[text_col].astype(str).fillna("").str.strip()

        if label_col is not None:
            out["label"] = df[label_col]
        else:
            out["label"] = pd.NA

        if "Stars" in df.columns:
            out["Stars"] = df["Stars"]
        elif "stars" in df.columns:
            out["Stars"] = df["stars"]
        else:
            out["Stars"] = pd.NA

        out["file_name"] = Path(path).name
        out = out[out["text"].str.len() > 0].copy()

        dfs.append(out)

    except Exception as e:
        failed.append((path, str(e)))

data = pd.concat(dfs, ignore_index=True)

print("Unified shape:", data.shape)
print(data.head())
print("\nMissing labels:", data["label"].isna().sum())
print("\nLabel distribution:")
print(data["label"].value_counts(dropna=False))
# Out:
# Unified shape: (19439, 4)
#                                                 text     label Stars  \
# 0   ماشاءالله اداء رائع بالتوفيق ان شاء الله EMO_NEU  positive     5
# 1  بالتوفيق اختي ليلي محتوي القناة زوين الله يوفق...  positive     5
# 2  محتوي جيد ومعلومات مفيده بدايه موفقه ليلي وبال...  positive     5
# 3  ليلا مغربيه تمدح مدينه بريده اهل بريده نائيمن ...  positive     5
# 4  ربي يخليك فتيحة امين يا رب العالمين لهلا يخطيك...  positive     5
#
#                                            file_name
# 0  dataset_youtube-comments-scraper_2025-11-13_07...
# 1  dataset_youtube-comments-scraper_2025-11-13_07...
# 2  dataset_youtube-comments-scraper_2025-11-13_07...
# 3  dataset_youtube-comments-scraper_2025-11-13_07...
# 4  dataset_youtube-comments-scraper_2025-11-13_07...
#
# Missing labels: 0
#
# Label distribution:
# label
# positive    9930
# negative    6458
# neutral     3051
# Name: count, dtype: int64

# %%
def normalize_label(x):
    if pd.isna(x):
        return pd.NA

    x = str(x).strip().lower()

    mapping = {
        "positive": "positive",
        "pos": "positive",
        "negative": "negative",
        "neg": "negative",
        "neutral": "neutral",
        "neu": "neutral",
        "mixed": "neutral"
    }

    return mapping.get(x, x)

data["label"] = data["label"].apply(normalize_label)

train_df = data.dropna(subset=["label"]).copy()
train_df = train_df[train_df["label"].isin(["positive", "negative", "neutral"])].copy()

print(train_df.shape)
print(train_df["label"].value_counts())
# Out:
# (19439, 4)
# label
# positive    9930
# negative    6458
# neutral     3051
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# =========================
# MULTI-CLASS MODEL WITH LIGHT GridSearchCV
# =========================
X_train_multi, X_val_multi, y_train_multi, y_val_multi = train_test_split(
    train_df["text"],
    train_df["label"],
    test_size=0.1,
    random_state=42,
    stratify=train_df["label"]
)

word_tfidf = TfidfVectorizer(
    analyzer="word",
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95,
    sublinear_tf=True
)

char_tfidf = TfidfVectorizer(
    analyzer="char_wb",
    ngram_range=(3, 5),
    min_df=2,
    max_df=0.95,
    sublinear_tf=True
)

features = FeatureUnion([
    ("word", word_tfidf),
    ("char", char_tfidf)
])

linear_svc_multi = Pipeline([
    ("features", features),
    ("clf", LinearSVC(random_state=42, max_iter=5000))
])

param_grid_multi = {
    "features__word__ngram_range": [(1, 2), (1, 3)],
    "features__char__ngram_range": [(3, 5), (3, 6)],
    "clf__C": [0.5, 1.0, 2.0],
    "clf__class_weight": [
        "balanced",
        {"negative": 1.0, "neutral": 2.0, "positive": 1.0},
        {"negative": 1.0, "neutral": 2.3, "positive": 1.0}
    ]
}

grid_multi = GridSearchCV(
    estimator=linear_svc_multi,
    param_grid=param_grid_multi,
    scoring="f1_macro",
    cv=2,
    n_jobs=-1,
    verbose=2
)

grid_multi.fit(X_train_multi, y_train_multi)

best_multi_model = grid_multi.best_estimator_
pred_multi = best_multi_model.predict(X_val_multi)

print("Best params (MULTI):", grid_multi.best_params_)
print("Best CV score (MULTI):", grid_multi.best_score_)
print("Validation Accuracy (MULTI):", accuracy_score(y_val_multi, pred_multi))
print()
print(classification_report(y_val_multi, pred_multi, digits=4))
print(confusion_matrix(y_val_multi, pred_multi))
# Out:
# Fitting 2 folds for each of 36 candidates, totalling 72 fits
# Best params (MULTI): {'clf__C': 0.5, 'clf__class_weight': 'balanced', 'features__char__ngram_range': (3, 5), 'features__word__ngram_range': (1, 3)}
# Best CV score (MULTI): 0.7291827934521007
# Validation Accuracy (MULTI): 0.8040123456790124
#
#               precision    recall  f1-score   support
#
#     negative     0.7614    0.8297    0.7941       646
#      neutral     0.6255    0.5475    0.5839       305
#     positive     0.8839    0.8661    0.8749       993
#
#     accuracy                         0.8040      1944
#    macro avg     0.7569    0.7478    0.7510      1944
# weighted avg     0.8026    0.8040    0.8024      1944
#
# [[536  50  60]
#  [ 85 167  53]
#  [ 83  50 860]]

# %%
# =========================
# BINARY MODEL WITH LIGHT GridSearchCV
# neutral removed completely
# =========================
binary_df = train_df[train_df["label"].isin(["positive", "negative"])].copy()

X_train_bin, X_val_bin, y_train_bin, y_val_bin = train_test_split(
    binary_df["text"],
    binary_df["label"],
    test_size=0.1,
    random_state=42,
    stratify=binary_df["label"]
)

linear_svc_binary = Pipeline([
    ("features", features),
    ("clf", LinearSVC(random_state=42, max_iter=5000))
])

param_grid_binary = {
    "features__word__ngram_range": [(1, 2), (1, 3)],
    "features__char__ngram_range": [(3, 5), (3, 6)],
    "clf__C": [0.5, 1.0, 2.0],
    "clf__class_weight": [
        "balanced",
        {"negative": 1.2, "positive": 1.0},
        {"negative": 1.4, "positive": 1.0}
    ]
}

grid_bin = GridSearchCV(
    estimator=linear_svc_binary,
    param_grid=param_grid_binary,
    scoring="f1_macro",
    cv=2,
    n_jobs=-1,
    verbose=2
)

grid_bin.fit(X_train_bin, y_train_bin)

best_binary_model = grid_bin.best_estimator_
pred_bin = best_binary_model.predict(X_val_bin)

print("Best params (BINARY):", grid_bin.best_params_)
print("Best CV score (BINARY):", grid_bin.best_score_)
print("Validation Accuracy (BINARY):", accuracy_score(y_val_bin, pred_bin))
print()
print(classification_report(y_val_bin, pred_bin, digits=4))
print(confusion_matrix(y_val_bin, pred_bin))
# Out:
# Fitting 2 folds for each of 36 candidates, totalling 72 fits
# Best params (BINARY): {'clf__C': 0.5, 'clf__class_weight': 'balanced', 'features__char__ngram_range': (3, 5), 'features__word__ngram_range': (1, 2)}
# Best CV score (BINARY): 0.8629952158981202
# Validation Accuracy (BINARY): 0.8926174496644296
#
#               precision    recall  f1-score   support
#
#     negative     0.8348    0.9071    0.8694       646
#     positive     0.9360    0.8832    0.9088       993
#
#     accuracy                         0.8926      1639
#    macro avg     0.8854    0.8952    0.8891      1639
# weighted avg     0.8961    0.8926    0.8933      1639
#
# [[586  60]
#  [116 877]]

# %%
import joblib

# حفظ مودل الثلاث كلاسات
joblib.dump(best_multi_model, "multi_class_svm.pkl")

# حفظ مودل الباينري
joblib.dump(best_binary_model, "binary_svm.pkl")

print("Models saved successfully ✅")
# Out:
# Models saved successfully ✅
