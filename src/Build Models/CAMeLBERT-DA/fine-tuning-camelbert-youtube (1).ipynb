# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-31-25-109_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-06-14-938_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-18-20-122_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-03-55-015_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-55-12-414_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-19-04-118_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-43-04-568_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-34-40-006_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-26-01-401_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-19-04-118_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-31-25-109_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-09-16-859_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-00-57-806_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-31-53-016_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-03-55-015_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-55-12-414_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-58-16-162_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-31-53-016_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-45-50-026_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-34-40-006_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-26-01-401_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-58-16-162_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_08-03-30-047_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_08-00-57-806_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-06-14-938_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-18-20-122_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_08-03-30-047_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-11_07-45-50-026_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-43-04-568_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-09-16-859_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-22-11-101_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-00-39-309_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_07-06-09-265_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-09-41-839_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-14-17-851_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-17-18-999_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-14-06-748_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-02-52-651_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-41-37-486_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-46-06-402_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-12-41-330_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-13-02-577_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-00-40-626_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-46-06-402_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_07-06-09-265_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-12-41-330_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-47-16-542_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-09-41-839_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-00-40-626_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-49-32-259_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-04-34-437_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-07-18-602_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637 (1)_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-22-11-101_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-17-18-999_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-47-16-542_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-42-43-199_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-36-33-457_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-36-33-457_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-07-18-602_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-04-34-437_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-37-52-679_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-04-35-896_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-39-26-660_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-35-59-847_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-06-16-575_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-09-07-823_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-06-16-575_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-13-02-577_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-41-37-486_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-14-17-851_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-17-30-937_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-35-59-847_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-37-52-679_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-11-08-637 (1)_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-25-24-979_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-28-43-748_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-28-43-748_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-25-24-979_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-09-07-823_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-04-35-896_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-39-26-660_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_05-58-34-900_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-27-34-645_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-49-32-259_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-14-06-748_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-00-39-309_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_01-02-52-651_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_06-27-34-645_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_09-17-30-937_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-11_05-58-34-900_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الوسطى/Youtube Data/الرياض/dataset_youtube-comments-scraper_2025-11-13_00-42-43-199_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 23_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 17_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 15_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 20_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 22_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 19_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 24_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 21_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 18_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 23_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 17_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 19_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 20_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 15_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 16_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 14_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 13_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/Najran Vedio Comments 7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة نجران - بعد المعالجة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 24_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 20_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 13_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 25_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 17_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 20_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 16_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 19_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 22_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 23_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 14_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 23_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 17_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 15_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 15_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 19_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 25_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 18_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 21_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة عسير - بعد المعالجة/Aseer Vedio Comments 6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 22_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 24_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 17_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 14_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 16_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 13_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 21_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 16_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 18_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 21_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 25_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 15_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 19_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الجنوبية/بيانات اليوتيوب لمنطقة جازان - بعد المعالجة/Jazan Vedio Comments 25_textready_cleaned.xlsx
# ...
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الجبيل/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/13_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/13_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الاحساء/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الدمام/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/7_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/5_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/2_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/6_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/4_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/10_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/5_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/1_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/1_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/3_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/7_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/12_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/3_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/9_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/2_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/12_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/9_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/8_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/8_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/10_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/6_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/11_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/4_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الشرقية/بيانات اليوتيوب للشرقية - بعد المعالجة/الخبر/11_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/معرض الوحي_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/معرض الوحي_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/مكة مول_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/مكة مول_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/معرض الوحي_textready.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/ابراج الساعة_textready_analysis.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/youtube_summary.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/ابراج الساعة_textready.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/ابراج الساعة_textready_cleaned.xlsx
# /kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/المنطقة الغربية/مكة/مكة مول_textready.xlsx

# %%
import os, glob, re, pickle
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix,f1_score
from sklearn.utils import resample

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout, SpatialDropout1D, GlobalMaxPooling1D
from tensorflow.keras.callbacks import ReduceLROnPlateau
# Out:
# 2026-04-19 09:34:12.782331: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776591253.166138      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776591253.281620      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776591254.300815      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776591254.300867      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776591254.300870      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776591254.300873      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# =========================================================
# (0) PATH + SETTINGS  (ALL REGIONS) + QUICK STRUCTURE CHECK
# =========================================================
ALL_REGIONS_ROOT = "/kaggle/input/datasets/ziyadaltalhi/youtube-data/YouTube Datasets - After Processing/"
TEXT_COL = "Text_TR"  # ✅ العمود المراد العمل عليه
STAR_CANDIDATES = {"stars", "Stars"}
print("\n[STEP 0] Path checks (ALL REGIONS)")
print("Root exists:", os.path.exists(ALL_REGIONS_ROOT))
print("Root is dir:", os.path.isdir(ALL_REGIONS_ROOT))

region_dirs = sorted([d for d in glob.glob(os.path.join(ALL_REGIONS_ROOT, "*")) if os.path.isdir(d)])
print("Region folders found:", len(region_dirs))
print("Regions:", [os.path.basename(d) for d in region_dirs])

# عرض سريع لأول 3 مناطق: عدد المدن داخل كل منطقة
for rd in region_dirs[:3]:
    city_dirs = sorted([d for d in glob.glob(os.path.join(rd, "*")) if os.path.isdir(d)])
    print(f"  - {os.path.basename(rd)}: cities={len(city_dirs)} (sample: {[os.path.basename(x) for x in city_dirs[:5]]})")
# Out:
# [STEP 0] Path checks (ALL REGIONS)
# Root exists: True
# Root is dir: True
# Region folders found: 5
# Regions: ['المنطقة الجنوبية', 'المنطقة الشرقية', 'المنطقة الشمالية', 'المنطقة الغربية', 'المنطقة الوسطى']
#   - المنطقة الجنوبية: cities=4 (sample: ['بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة', 'بيانات اليوتيوب لمنطقة جازان - بعد المعالجة', 'بيانات اليوتيوب لمنطقة عسير - بعد المعالجة', 'بيانات اليوتيوب لمنطقة نجران - بعد المعالجة'])
#   - المنطقة الشرقية: cities=1 (sample: ['بيانات اليوتيوب للشرقية - بعد المعالجة'])
#   - المنطقة الشمالية: cities=1 (sample: ['( المنطقة الشمالية ) Youtube Data -  After Preproccesing'])

# %%
# =========================================================
# Helpers: extract region name (inside parentheses) + city
# =========================================================
PAREN_RE = re.compile(r"\((.*?)\)")

def extract_region_from_folder(region_folder_name: str) -> str:
    """
    يستخرج النص بين ( ) من اسم مجلد المنطقة.
    مثال: "( المنطقة الغربية ) Google Maps Data - After Cleaning" -> "المنطقة الغربية"
    إذا لم توجد أقواس يرجع اسم المجلد نفسه.
    """
    m = PAREN_RE.search(region_folder_name)
    if m:
        return m.group(1).strip()
    return region_folder_name.strip()

def list_region_folders(root_folder: str):
    region_dirs = sorted([d for d in glob.glob(os.path.join(root_folder, "*")) if os.path.isdir(d)])
    return region_dirs

def list_city_folders(region_dir: str):
    return sorted([d for d in glob.glob(os.path.join(region_dir, "*")) if os.path.isdir(d)])

def list_files_in_city(city_dir: str):
    return (
        glob.glob(os.path.join(city_dir, "*.xlsx")) +
        glob.glob(os.path.join(city_dir, "*.xls")) +
        glob.glob(os.path.join(city_dir, "*.csv"))
    )

def read_any_file(path: str) -> pd.DataFrame:
    ext = os.path.splitext(path)[1].lower()
    if ext in [".xlsx", ".xls"]:
        df = pd.read_excel(path)
    elif ext == ".csv":
        # ترميزات عربية شائعة
        try:
            df = pd.read_csv(path, encoding="utf-8")
        except UnicodeDecodeError:
            try:
                df = pd.read_csv(path, encoding="utf-8-sig")
            except UnicodeDecodeError:
                df = pd.read_csv(path, encoding="cp1256")
    else:
        raise ValueError(f"Unsupported extension: {ext}")
    df.columns = [str(c).strip() for c in df.columns]
    return df

def standardize_star_column(df: pd.DataFrame) -> pd.DataFrame:
    """
    - يقبل Stars / stars / ... ويوحّدها إلى عمود اسمه 'Stars' إن وجد.
    - لا يغير القيم الآن.
    """
    colmap = {c.lower(): c for c in df.columns}
    # إذا موجود Stars بالاسم الصحيح خلاص
    if "Stars" in df.columns:
        return df

    # ابحث عن أي عمود اسمه stars case-insensitive
    if "stars" in colmap:
        df = df.rename(columns={colmap["stars"]: "Stars"})
        return df

    # مرونة إضافية: إذا فيه rating مثلا
    for cand in list(STAR_CANDIDATES):
        key = cand.lower()
        if key in colmap:
            df = df.rename(columns={colmap[key]: "Stars"})
            return df

    return df  # لم نجد عمود نجوم

# %%
import os
import pandas as pd



# =========================================================
# (1) GET ALL VALID FILES (RECURSIVE)
# =========================================================
def get_analysis_files_recursive(region_path):
    files = []

    for root, dirs, filenames in os.walk(region_path):
        for fname in filenames:
            name = fname.lower()
            fpath = os.path.join(root, fname)

            if (
                name.endswith((".xlsx", ".xls")) and
                "analysis" in name and
                "summary" not in name
            ):
                files.append(fpath)

    return files


# =========================================================
# (2) SCAN AVAILABILITY
# =========================================================
def scan_availability(root_folder: str):
    rows = []

    for rd in list_region_folders(root_folder):
        region_folder = os.path.basename(rd)
        region_name = extract_region_from_folder(region_folder)

        files = get_analysis_files_recursive(rd)

        rows.append({
            "Region_Folder": region_folder,
            "Region_Name": region_name,
            "Files": len(files),
            "Sample_File": files[0] if files else None
        })

    return pd.DataFrame(rows).sort_values("Files", ascending=False).reset_index(drop=True)


# =========================================================
# (3) READ ALL REGIONS (CHUNKED)
# =========================================================
def read_all_regions_chunked(root_folder: str, max_files_per_region=None, keep_columns=None):

    all_frames = []
    report_rows = []

    region_dirs = list_region_folders(root_folder)

    for r_idx, rd in enumerate(region_dirs, 1):
        region_folder = os.path.basename(rd)
        region_name = extract_region_from_folder(region_folder)

        region_files = get_analysis_files_recursive(rd)

        if max_files_per_region is not None:
            region_files = region_files[:max_files_per_region]

        print(f"\n[STEP 1] Region {r_idx}/{len(region_dirs)}: {region_name} | files={len(region_files)}")

        n_rows_region = 0
        has_text = 0
        has_stars = 0
        read_ok = 0
        read_err = 0

        for i, p in enumerate(region_files, 1):
            try:
                df = read_any_file(p)
                df = standardize_star_column(df)

                # استخراج اسم المدينة بشكل ذكي
                city_name = os.path.basename(os.path.dirname(p))
                if city_name.startswith("Tik_"):
                    city_name = os.path.basename(os.path.dirname(os.path.dirname(p)))

                df["Region_Folder"] = region_folder
                df["Region_Name"] = region_name
                df["City_Folder"] = city_name
                df["Source_File"] = os.path.basename(p)
                df["__path__"] = p

                # تحقق من الأعمدة
                if TEXT_COL in df.columns:
                    has_text += 1
                if "Stars" in df.columns:
                    has_stars += 1


                # تقليل الأعمدة (اختياري)
                if keep_columns is not None:
                    keep = [c for c in keep_columns if c in df.columns]
                    meta = ["Region_Folder","Region_Name","City_Folder","Source_File","__path__"]
                    keep = list(dict.fromkeys(keep + meta))
                    df = df[keep].copy()

                n_rows_region += len(df)
                all_frames.append(df)
                read_ok += 1

                if i <= 2:
                    print(f"  sample file [{i}] {region_name}/{city_name}/{os.path.basename(p)} rows={len(df)}")

                if i % 50 == 0:
                    print(f"  progress: {i}/{len(region_files)} files")

            except Exception as e:
                read_err += 1
                print(f"❌ Error reading: {p}")

        report_rows.append({
            "Region_Name": region_name,
            "Region_Folder": region_folder,
            "Files_Read_OK": read_ok,
            "Files_Read_Err": read_err,
            "Files_with_Text": has_text,
            "Files_with_Stars": has_stars,
            "Total_Rows_This_Region": n_rows_region
        })

    df_region_report = pd.DataFrame(report_rows) \
        .sort_values("Total_Rows_This_Region", ascending=False) \
        .reset_index(drop=True)

    df_all = pd.concat(all_frames, ignore_index=True) if all_frames else pd.DataFrame()

    return df_all, df_region_report


# =========================================================
# (4) RUN
# =========================================================

print("\n[STEP 1A] Availability per region:")
df_av = scan_availability(ALL_REGIONS_ROOT)
display(df_av)

KEEP_COLS = [
    TEXT_COL,
    "Stars",
    
]

df1, df_region_report = read_all_regions_chunked(
    ALL_REGIONS_ROOT,
    max_files_per_region=None,
    keep_columns=KEEP_COLS
)

print("\n[STEP 1B] Column availability per region:")
display(df_region_report)

print("\n[STEP 1 RESULT] df1 shape:", df1.shape)
print("Columns:", df1.columns.tolist())
# Out:
# [STEP 1A] Availability per region:
#       Region_Folder       Region_Name  Files  \
# 0  المنطقة الجنوبية  المنطقة الجنوبية     82
# 1    المنطقة الوسطى    المنطقة الوسطى     47
# 2   المنطقة الشرقية   المنطقة الشرقية     46
# 3  المنطقة الشمالية  المنطقة الشمالية     20
# 4   المنطقة الغربية   المنطقة الغربية      3
#
#                                          Sample_File
# 0  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 1  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 2  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 3  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 4  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# [STEP 1] Region 1/5: المنطقة الجنوبية | files=82
#   sample file [1] المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 18_textready_analysis.xlsx rows=26
#   sample file [2] المنطقة الجنوبية/بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة/Al-Baha Vedio Comments 24_textready_analysis.xlsx rows=45
#   progress: 50/82 files
#
# [STEP 1] Region 2/5: المنطقة الشرقية | files=46
#   sample file [1] المنطقة الشرقية/الجبيل/7_textready_analysis.xlsx rows=0
#   sample file [2] المنطقة الشرقية/الجبيل/4_textready_analysis.xlsx rows=1
#
# [STEP 1] Region 3/5: المنطقة الشمالية | files=20
#   sample file [1] المنطقة الشمالية/تبوك/وادي الديسة_textready_analysis.xlsx rows=526
#   sample file [2] المنطقة الشمالية/تبوك/تبوك_textready_analysis.xlsx rows=780
#
# [STEP 1] Region 4/5: المنطقة الغربية | files=3
#   sample file [1] المنطقة الغربية/مكة/معرض الوحي_textready_analysis.xlsx rows=56
#   sample file [2] المنطقة الغربية/مكة/مكة مول_textready_analysis.xlsx rows=65
#
# [STEP 1] Region 5/5: المنطقة الوسطى | files=47
#   sample file [1] المنطقة الوسطى/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-31-25-109_textready_analysis.xlsx rows=11
#   sample file [2] المنطقة الوسطى/القصيم/dataset_youtube-comments-scraper_2025-11-13_07-19-04-118_textready_analysis.xlsx rows=283
#
# [STEP 1B] Column availability per region:
#         Region_Name     Region_Folder  Files_Read_OK  Files_Read_Err  \
# 0  المنطقة الجنوبية  المنطقة الجنوبية             82               0
# 1    المنطقة الوسطى    المنطقة الوسطى             47               0
# 2  المنطقة الشمالية  المنطقة الشمالية             20               0
# 3   المنطقة الشرقية   المنطقة الشرقية             46               0
# 4   المنطقة الغربية   المنطقة الغربية              3               0
#
#    Files_with_Text  Files_with_Stars  Total_Rows_This_Region
# 0               82                82                    9240
# 1               47                47                    5097
# 2               20                20                    4499
# 3               46                46                     387
# 4                3                 3                     216
# [STEP 1 RESULT] df1 shape: (19439, 7)
# Columns: ['Text_TR', 'Stars', 'Region_Folder', 'Region_Name', 'City_Folder', 'Source_File', '__path__']

# %%
df1['Stars'].value_counts()
# Out:
# Stars
# 5    9930
# 1    6458
# 3    3051
# Name: count, dtype: int64

# %%
# =========================================================
# (2) FILTER ONLY TRULY-EMPTY Text_TR (NaN + "" + "nan" + "[]" ...)
# =========================================================
print(f"\n[STEP 2] Using {TEXT_COL} + strong empty filter")

# ✅ الداتا الجديدة
if TEXT_COL not in df1.columns:
    raise ValueError(f"عمود {TEXT_COL} غير موجود في البيانات.")

before2 = len(df1)

# لا نحول إلى string الآن (مهم)
s = df1[TEXT_COL]

empty_like = {
    "", "nan", "NaN", "none", "None", "NONE",
    "<NA>", "[]", "[ ]", "{}", "null", "NULL"
}

empty_mask = (
    s.isna() |
    s.astype(str).str.strip().isin(empty_like)
)

empty_count = int(empty_mask.sum())

# ✅ الناتج الجديد
df2 = df1.loc[~empty_mask].copy()

# العمود الذي سيستخدم لاحقاً للمودل
df2["TEXT_FOR_MODEL"] = df2[TEXT_COL].astype(str).str.strip()

print("\n[STEP 2 RESULT]")
print("Rows before:", before2)
print("Empty-like rows:", empty_count)
print("Rows after:", len(df2))

print("\nSample empty-like values:")
print(s.loc[empty_mask].head(10).astype(str).tolist())
# Out:
# [STEP 2] Using Text_TR + strong empty filter
#
# [STEP 2 RESULT]
# Rows before: 19439
# Empty-like rows: 0
# Rows after: 19439
#
# Sample empty-like values:
# []

# %%
import re
import pandas as pd

print("\n[STEP 4] Safe Cleaning (Text Only)")

TEXT_COL = "Text_TR"

if TEXT_COL not in df2.columns:
    raise ValueError(f"{TEXT_COL} غير موجود في df2")

# =========================
# Regex definitions
# =========================
AR_DIACRITICS_RE = re.compile(r"[\u0617-\u061A\u064B-\u0652\u0670]")
AR_TATWEEL_RE    = re.compile(r"\u0640")

# =========================
# Arabic normalization
# =========================
def normalize_arabic_safe(text: str) -> str:
    text = AR_DIACRITICS_RE.sub("", text)
    text = AR_TATWEEL_RE.sub("", text)
    text = re.sub(r"[إأآا]", "ا", text)
    return text

# =========================
# Main cleaning function
# =========================
def clean_text(s):
    if pd.isna(s):
        return ""

    s = str(s).strip().lower()
    if not s:
        return ""

    # remove links / emails / mentions / hashtags
    s = re.sub(r"http\S+|www\.\S+", " ", s)
    s = re.sub(r"\S+@\S+", " ", s)
    s = re.sub(r"@\w+", " ", s)
    s = re.sub(r"#\w+", " ", s)

    # remove emojis
    s = re.sub(r"[\U00010000-\U0010ffff]", " ", s)

    # keep Arabic / English / digits / spaces
    s = re.sub(r"[^0-9a-z\u0600-\u06FF\s]", " ", s)

    # normalize Arabic
    s = normalize_arabic_safe(s)

    # reduce repeated letters
    s = re.sub(r"(.)\1{2,}", r"\1\1", s)

    # collapse spaces
    s = re.sub(r"\s+", " ", s).strip()

    # remove numbers only
    if re.fullmatch(r"\d+", s):
        return ""

    return s


# =========================
# BEFORE cleaning view
# =========================
df_before_clean = df2[[TEXT_COL]].copy()
df_before_clean = df_before_clean.rename(columns={TEXT_COL: "text_before"})

display(df_before_clean.head(10))


# =========================
# Apply cleaning
# =========================
df4 = df2.copy()
df4["text_clean"] = df4[TEXT_COL].apply(clean_text)


# =========================
# Compare
# =========================
df_compare = pd.DataFrame({
    "text_before": df2[TEXT_COL],
    "text_clean": df4["text_clean"]
})

display(df_compare.head(20))


# =========================
# Removed rows
# =========================
df_removed = df_compare[df_compare["text_clean"].str.len() == 0]

print("Removed rows:", len(df_removed))
display(df_removed.head(20))


# =========================
# Final dataset
# =========================
df4 = df_compare[df_compare["text_clean"].str.len() > 0]

print("Final shape:", df4.shape)
display(df4.head(20))


# =========================
# Test examples
# =========================
print("\n[CHECK] examples:")
for t in ["سييييئ جدا", "المكان رائع!!!", "http://test.com", "12345", "مطعم جميل"]:
    print(t, "->", clean_text(t))
# Out:
# [STEP 4] Safe Cleaning (Independent)
#                                          text_before Stars       Region_Name  \
# 0  لقد عملت مدرسا في ثانوية رغدان لمدة خمس سنوات ...     5  المنطقة الجنوبية
# 1  منتزه جميل ومخدوم ومنظم جئته قبل 40 سنة تقريبا...     5  المنطقة الجنوبية
# 2  سبحان الله والحمد لله ولا اله الا الله والله اكبر     5  المنطقة الجنوبية
# 3  انا ام عندي 62سنة ابنتي عندها 19 سنة محبين الق...     5  المنطقة الجنوبية
# 4  ماشاء الله اللهم صل وسلم وبارك علي سيدنا محمد ...     5  المنطقة الجنوبية
# 5  ما شاء الله تبارك الرحمن المنطقة جمالها رائع ت...     5  المنطقة الجنوبية
# 6  ماشاءالله تبارك الله عليك يا شيخنا الفاضل ايه ...     5  المنطقة الجنوبية
# 7  ١ نعم ٢ لا يوجد صعوبة ٣ نعم الاسعار غالية قليل...     5  المنطقة الجنوبية
# 8  جزاك الله خير ياخوي محمد وبيض الله وجهك علي ما...     5  المنطقة الجنوبية
# 9  الله يوفقك اخي في الله واسال الله العظيم رب ال...     5  المنطقة الجنوبية
#
#       Region_Folder                                   City_Folder  \
# 0  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 1  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 2  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 3  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 4  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 5  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 6  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 7  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 8  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 9  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
#
#                                          Source_File  \
# 0  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 1  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 2  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 3  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 4  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 5  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 6  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 7  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 8  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 9  Al-Baha Vedio Comments 18_textready_analysis.xlsx
#
#                                             __path__
# 0  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 1  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 2  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 3  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 4  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 5  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 6  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 7  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 8  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 9  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
#                                           text_before  \
# 0   لقد عملت مدرسا في ثانوية رغدان لمدة خمس سنوات ...
# 1   منتزه جميل ومخدوم ومنظم جئته قبل 40 سنة تقريبا...
# 2   سبحان الله والحمد لله ولا اله الا الله والله اكبر
# 3   انا ام عندي 62سنة ابنتي عندها 19 سنة محبين الق...
# 4   ماشاء الله اللهم صل وسلم وبارك علي سيدنا محمد ...
# 5   ما شاء الله تبارك الرحمن المنطقة جمالها رائع ت...
# 6   ماشاءالله تبارك الله عليك يا شيخنا الفاضل ايه ...
# 7   ١ نعم ٢ لا يوجد صعوبة ٣ نعم الاسعار غالية قليل...
# 8   جزاك الله خير ياخوي محمد وبيض الله وجهك علي ما...
# 9   الله يوفقك اخي في الله واسال الله العظيم رب ال...
# 10                ماشاء الله تبارك الله احسن الخالقين
# 11  ماشاءالله ما هذا الجميل ربي يرزقني الحياه في ا...
# 12  اللهم اسعده ووفقه وبارك له واتم عليه الخير وال...
# 13  تبارك الله منظر جميل جدا جزاك الله بخير شيخي ا...
# 14  اللهم صل و سلم علي نبينا و حبيبنا محمد وعلي ال...
# 15  كل مانروح باحه نروح لها مرهه تجنن وكمان منتزه ...
# 16  اللهم صل وسلم وبارك علي سيدنا ونبينا محمد وعلي...
# 17                     نطقك لكلمة هيل خطا يا شيخ محمد
# 18          انا من كتابتك نمنا زياره ال موسي التراثية
# 19  اللهم ارزقنا زياره هذا المكان الجميل واجعلنا م...
#
#                                            text_clean Stars       Region_Name  \
# 0   لقد عملت مدرسا في ثانوية رغدان لمدة خمس سنوات ...     5  المنطقة الجنوبية
# 1   منتزه جميل ومخدوم ومنظم جئته قبل 40 سنة تقريبا...     5  المنطقة الجنوبية
# 2   سبحان الله والحمد لله ولا اله الا الله والله اكبر     5  المنطقة الجنوبية
# 3   انا ام عندي 62سنة ابنتي عندها 19 سنة محبين الق...     5  المنطقة الجنوبية
# 4   ماشاء الله اللهم صل وسلم وبارك علي سيدنا محمد ...     5  المنطقة الجنوبية
# 5   ما شاء الله تبارك الرحمن المنطقة جمالها رائع ت...     5  المنطقة الجنوبية
# 6   ماشاءالله تبارك الله عليك يا شيخنا الفاضل ايه ...     5  المنطقة الجنوبية
# 7   ١ نعم ٢ لا يوجد صعوبة ٣ نعم الاسعار غالية قليل...     5  المنطقة الجنوبية
# 8   جزاك الله خير ياخوي محمد وبيض الله وجهك علي ما...     5  المنطقة الجنوبية
# 9   الله يوفقك اخي في الله واسال الله العظيم رب ال...     5  المنطقة الجنوبية
# 10                ماشاء الله تبارك الله احسن الخالقين     5  المنطقة الجنوبية
# 11  ماشاءالله ما هذا الجميل ربي يرزقني الحياه في ا...     5  المنطقة الجنوبية
# 12  اللهم اسعده ووفقه وبارك له واتم عليه الخير وال...     5  المنطقة الجنوبية
# 13  تبارك الله منظر جميل جدا جزاك الله بخير شيخي ا...     5  المنطقة الجنوبية
# 14  اللهم صل و سلم علي نبينا و حبيبنا محمد وعلي ال...     5  المنطقة الجنوبية
# 15  كل مانروح باحه نروح لها مرهه تجنن وكمان منتزه ...     5  المنطقة الجنوبية
# 16  اللهم صل وسلم وبارك علي سيدنا ونبينا محمد وعلي...     5  المنطقة الجنوبية
# 17                     نطقك لكلمة هيل خطا يا شيخ محمد     1  المنطقة الجنوبية
# 18          انا من كتابتك نمنا زياره ال موسي التراثية     5  المنطقة الجنوبية
# 19  اللهم ارزقنا زياره هذا المكان الجميل واجعلنا م...     5  المنطقة الجنوبية
#
#        Region_Folder                                   City_Folder  \
# 0   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 1   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 2   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 3   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 4   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 5   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 6   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 7   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 8   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 9   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 10  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 11  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 12  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 13  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 14  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 15  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 16  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 17  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 18  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 19  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
#
#                                           Source_File  \
# 0   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 1   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 2   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 3   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 4   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 5   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 6   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 7   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 8   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 9   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 10  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 11  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 12  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 13  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 14  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 15  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 16  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 17  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 18  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 19  Al-Baha Vedio Comments 18_textready_analysis.xlsx
#
#                                              __path__
# 0   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 1   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 2   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 3   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 4   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 5   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 6   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 7   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 8   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 9   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 10  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 11  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 12  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 13  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 14  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 15  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 16  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 17  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 18  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 19  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# Removed rows (empty after clean): 0
# Empty DataFrame
# Columns: [text_before, text_clean, Stars, Region_Name, Region_Folder, City_Folder, Source_File, __path__]
# Index: []
# Final cleaned shape: (19439, 8)
# Columns: ['text_before', 'text_clean', 'Stars', 'Region_Name', 'Region_Folder', 'City_Folder', 'Source_File', '__path__']
#                                           text_before  \
# 0   لقد عملت مدرسا في ثانوية رغدان لمدة خمس سنوات ...
# 1   منتزه جميل ومخدوم ومنظم جئته قبل 40 سنة تقريبا...
# 2   سبحان الله والحمد لله ولا اله الا الله والله اكبر
# 3   انا ام عندي 62سنة ابنتي عندها 19 سنة محبين الق...
# 4   ماشاء الله اللهم صل وسلم وبارك علي سيدنا محمد ...
# 5   ما شاء الله تبارك الرحمن المنطقة جمالها رائع ت...
# 6   ماشاءالله تبارك الله عليك يا شيخنا الفاضل ايه ...
# 7   ١ نعم ٢ لا يوجد صعوبة ٣ نعم الاسعار غالية قليل...
# 8   جزاك الله خير ياخوي محمد وبيض الله وجهك علي ما...
# 9   الله يوفقك اخي في الله واسال الله العظيم رب ال...
# 10                ماشاء الله تبارك الله احسن الخالقين
# 11  ماشاءالله ما هذا الجميل ربي يرزقني الحياه في ا...
# 12  اللهم اسعده ووفقه وبارك له واتم عليه الخير وال...
# 13  تبارك الله منظر جميل جدا جزاك الله بخير شيخي ا...
# 14  اللهم صل و سلم علي نبينا و حبيبنا محمد وعلي ال...
# 15  كل مانروح باحه نروح لها مرهه تجنن وكمان منتزه ...
# 16  اللهم صل وسلم وبارك علي سيدنا ونبينا محمد وعلي...
# 17                     نطقك لكلمة هيل خطا يا شيخ محمد
# 18          انا من كتابتك نمنا زياره ال موسي التراثية
# 19  اللهم ارزقنا زياره هذا المكان الجميل واجعلنا م...
#
#                                            text_clean Stars       Region_Name  \
# 0   لقد عملت مدرسا في ثانوية رغدان لمدة خمس سنوات ...     5  المنطقة الجنوبية
# 1   منتزه جميل ومخدوم ومنظم جئته قبل 40 سنة تقريبا...     5  المنطقة الجنوبية
# 2   سبحان الله والحمد لله ولا اله الا الله والله اكبر     5  المنطقة الجنوبية
# 3   انا ام عندي 62سنة ابنتي عندها 19 سنة محبين الق...     5  المنطقة الجنوبية
# 4   ماشاء الله اللهم صل وسلم وبارك علي سيدنا محمد ...     5  المنطقة الجنوبية
# 5   ما شاء الله تبارك الرحمن المنطقة جمالها رائع ت...     5  المنطقة الجنوبية
# 6   ماشاءالله تبارك الله عليك يا شيخنا الفاضل ايه ...     5  المنطقة الجنوبية
# 7   ١ نعم ٢ لا يوجد صعوبة ٣ نعم الاسعار غالية قليل...     5  المنطقة الجنوبية
# 8   جزاك الله خير ياخوي محمد وبيض الله وجهك علي ما...     5  المنطقة الجنوبية
# 9   الله يوفقك اخي في الله واسال الله العظيم رب ال...     5  المنطقة الجنوبية
# 10                ماشاء الله تبارك الله احسن الخالقين     5  المنطقة الجنوبية
# 11  ماشاءالله ما هذا الجميل ربي يرزقني الحياه في ا...     5  المنطقة الجنوبية
# 12  اللهم اسعده ووفقه وبارك له واتم عليه الخير وال...     5  المنطقة الجنوبية
# 13  تبارك الله منظر جميل جدا جزاك الله بخير شيخي ا...     5  المنطقة الجنوبية
# 14  اللهم صل و سلم علي نبينا و حبيبنا محمد وعلي ال...     5  المنطقة الجنوبية
# 15  كل مانروح باحه نروح لها مرهه تجنن وكمان منتزه ...     5  المنطقة الجنوبية
# 16  اللهم صل وسلم وبارك علي سيدنا ونبينا محمد وعلي...     5  المنطقة الجنوبية
# 17                     نطقك لكلمة هيل خطا يا شيخ محمد     1  المنطقة الجنوبية
# 18          انا من كتابتك نمنا زياره ال موسي التراثية     5  المنطقة الجنوبية
# 19  اللهم ارزقنا زياره هذا المكان الجميل واجعلنا م...     5  المنطقة الجنوبية
#
#        Region_Folder                                   City_Folder  \
# 0   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 1   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 2   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 3   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 4   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 5   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 6   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 7   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 8   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 9   المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 10  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 11  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 12  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 13  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 14  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 15  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 16  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 17  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 18  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 19  المنطقة الجنوبية  بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
#
#                                           Source_File  \
# 0   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 1   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 2   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 3   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 4   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 5   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 6   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 7   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 8   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 9   Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 10  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 11  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 12  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 13  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 14  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 15  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 16  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 17  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 18  Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 19  Al-Baha Vedio Comments 18_textready_analysis.xlsx
#
#                                              __path__
# 0   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 1   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 2   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 3   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 4   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 5   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 6   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 7   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 8   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 9   /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 10  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 11  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 12  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 13  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 14  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 15  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 16  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 17  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 18  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# 19  /kaggle/input/datasets/ziyadaltalhi/youtube-da...
# [CHECK] safe normalization examples:
# سيئ  ->  سيئ
# سيئة  ->  سيئة
# سيء  ->  سيء
# المكان سيئ جدا  ->  المكان سيئ جدا
# المكان رائع جدا  ->  المكان رائع جدا
# 12345  ->
# مطعم 123  ->  مطعم 123

# %%
df4 = df4[df4["Stars"] != 3]

# %%
def convert_stars(star):
    if star >= 4:
        return 1  # إيجابي
    else:
        return 0  # سلبي

df4["label"] = df4["Stars"].apply(convert_stars)

# %%
df4
# Out:
#                                              text_before  \
# 0      لقد عملت مدرسا في ثانوية رغدان لمدة خمس سنوات ...
# 1      منتزه جميل ومخدوم ومنظم جئته قبل 40 سنة تقريبا...
# 2      سبحان الله والحمد لله ولا اله الا الله والله اكبر
# 3      انا ام عندي 62سنة ابنتي عندها 19 سنة محبين الق...
# 4      ماشاء الله اللهم صل وسلم وبارك علي سيدنا محمد ...
# ...                                                  ...
# 19432                                    بارده حيل ول لا
# 19433              3 منوعات حسين العلوي بعد الدائري شكرا
# 19436    يسلموو علي المرور الجميل وعلي التشجيع اخت عواطف
# 19437          رنا 45 حياكم الله 140 للكبير و 120 للصغير
# 19438  مرورك الاجمل ابومحمد _ عقبال ماتجيب حمود وعلاو...
#
#                                               text_clean Stars  \
# 0      لقد عملت مدرسا في ثانوية رغدان لمدة خمس سنوات ...     5
# 1      منتزه جميل ومخدوم ومنظم جئته قبل 40 سنة تقريبا...     5
# 2      سبحان الله والحمد لله ولا اله الا الله والله اكبر     5
# 3      انا ام عندي 62سنة ابنتي عندها 19 سنة محبين الق...     5
# 4      ماشاء الله اللهم صل وسلم وبارك علي سيدنا محمد ...     5
# ...                                                  ...   ...
# 19432                                    بارده حيل ول لا     1
# 19433              3 منوعات حسين العلوي بعد الدائري شكرا     5
# 19436    يسلموو علي المرور الجميل وعلي التشجيع اخت عواطف     5
# 19437          رنا 45 حياكم الله 140 للكبير و 120 للصغير     5
# 19438  مرورك الاجمل ابومحمد عقبال ماتجيب حمود وعلاوي ...     5
#
#             Region_Name     Region_Folder  \
# 0      المنطقة الجنوبية  المنطقة الجنوبية
# 1      المنطقة الجنوبية  المنطقة الجنوبية
# 2      المنطقة الجنوبية  المنطقة الجنوبية
# 3      المنطقة الجنوبية  المنطقة الجنوبية
# 4      المنطقة الجنوبية  المنطقة الجنوبية
# ...                 ...               ...
# 19432    المنطقة الوسطى    المنطقة الوسطى
# 19433    المنطقة الوسطى    المنطقة الوسطى
# 19436    المنطقة الوسطى    المنطقة الوسطى
# 19437    المنطقة الوسطى    المنطقة الوسطى
# 19438    المنطقة الوسطى    المنطقة الوسطى
#
#                                         City_Folder  \
# 0      بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 1      بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 2      بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 3      بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# 4      بيانات اليوتيوب لمنطقة الباحة - بعد المعالجة
# ...                                             ...
# 19432                                        الرياض
# 19433                                        الرياض
# 19436                                        الرياض
# 19437                                        الرياض
# 19438                                        الرياض
#
#                                              Source_File  \
# 0      Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 1      Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 2      Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 3      Al-Baha Vedio Comments 18_textready_analysis.xlsx
# 4      Al-Baha Vedio Comments 18_textready_analysis.xlsx
# ...                                                  ...
# 19432  dataset_youtube-comments-scraper_2025-11-13_00...
# 19433  dataset_youtube-comments-scraper_2025-11-13_00...
# 19436  dataset_youtube-comments-scraper_2025-11-13_00...
# 19437  dataset_youtube-comments-scraper_2025-11-13_00...
# 19438  dataset_youtube-comments-scraper_2025-11-13_00...
#
#                                                 __path__  label
# 0      /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# 1      /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# 2      /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# 3      /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# 4      /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# ...                                                  ...    ...
# 19432  /kaggle/input/datasets/ziyadaltalhi/youtube-da...      0
# 19433  /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# 19436  /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# 19437  /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
# 19438  /kaggle/input/datasets/ziyadaltalhi/youtube-da...      1
#
# [16388 rows x 9 columns]

# %%
print(df4["label"].value_counts())
# Out:
# label
# 1    9930
# 0    6458
# Name: count, dtype: int64

# %%
df5 = df4[["text_clean", "label"]].dropna()

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(df5)
dataset = dataset.train_test_split(test_size=0.2)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text_clean', 'label', '__index_level_0__'],
#         num_rows: 13110
#     })
#     test: Dataset({
#         features: ['text_clean', 'label', '__index_level_0__'],
#         num_rows: 3278
#     })
# })

# %%
from imblearn.over_sampling import RandomOverSampler

# 2) تحويل train إلى pandas
train_df = dataset["train"].to_pandas()

# 3) فصل X و y (فقط على train)
X = train_df[["text_clean"]]
y = train_df["label"]

# 4) تطبيق oversampling
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)

# 5) إعادة الدمج
train_balanced = pd.concat([X_resampled, y_resampled], axis=1)

# 6) خلط البيانات
train_balanced = train_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# 7) إرجاعه إلى Dataset
dataset["train"] = Dataset.from_pandas(train_balanced)

# %%
print(dataset["train"].to_pandas()["label"].value_counts())
print(dataset["test"].to_pandas()["label"].value_counts())
# Out:
# label
# 1    7915
# 0    7915
# Name: count, dtype: int64
# label
# 1    2015
# 0    1263
# Name: count, dtype: int64

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2,
    ignore_mismatched_sizes=True
)

# تعريف اللابلز (مهم)
model.config.id2label = {0: "Negative", 1: "Positive"}
model.config.label2id = {"Negative": 0, "Positive": 1}
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment
# Key                          | Status     |
# -----------------------------+------------+-------------------------------------------------------------------------------------
# bert.embeddings.position_ids | UNEXPECTED |
# classifier.bias              | MISMATCH   | Reinit due to size mismatch ckpt: torch.Size([3]) vs model:torch.Size([2])
# classifier.weight            | MISMATCH   | Reinit due to size mismatch ckpt: torch.Size([3, 768]) vs model:torch.Size([2, 768])
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISMATCH	:ckpt weights were loaded, but they did not match the original empty weight shapes.

# %%
def tokenize(batch):
    return tokenizer(batch["text_clean"], truncation=True, padding="max_length", max_length=128)

dataset = Dataset.from_pandas(df5).train_test_split(test_size=0.2)
dataset = dataset.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/13110 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3278 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./camel_binary",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    num_train_epochs=5,
    logging_dir="./logs",
    save_steps=0   # مهم لتجنب الخطأ عندك
)
# Out:
# `logging_dir` is deprecated and will be removed in v5.2. Please set `TENSORBOARD_LOGGING_DIR` instead.

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"]
)
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
#     <div>
#
#       <progress value='2050' max='2050' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2050/2050 15:23, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.265572</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.105534</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.046999</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.014773</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=2050, training_loss=0.10578699010174449, metrics={'train_runtime': 924.2709, 'train_samples_per_second': 70.921, 'train_steps_per_second': 2.218, 'total_flos': 4311732419712000.0, 'train_loss': 0.10578699010174449, 'epoch': 5.0})

# %%
pred_output = trainer.predict(dataset["test"])

y_true = pred_output.label_ids
y_pred = pred_output.predictions.argmax(axis=1)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

print("Accuracy:", accuracy_score(y_true, y_pred))
print("F1 Macro:", f1_score(y_true, y_pred, average="macro"))
print("Precision Macro:", precision_score(y_true, y_pred, average="macro"))
print("Recall Macro:", recall_score(y_true, y_pred, average="macro"))
# Out:
# Accuracy: 0.9682733374008542
# F1 Macro: 0.9670322996661376
# Precision Macro: 0.969889573703133
# Recall Macro: 0.9646007996011228

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=["Negative", "Positive"],
            yticklabels=["Negative", "Positive"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

pred_output = trainer.predict(dataset["test"])

y_true = pred_output.label_ids
y_pred = pred_output.predictions.argmax(axis=1)

report = classification_report(
    y_true,
    y_pred,
    target_names=["Negative", "Positive"],
    digits=2
)

print(report)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py:583: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   return super().apply(*args, **kwargs)  # type: ignore[misc]
#               precision    recall  f1-score   support
#
#     Negative       0.98      0.94      0.96      1344
#     Positive       0.96      0.99      0.97      1934
#
#     accuracy                           0.97      3278
#    macro avg       0.97      0.96      0.97      3278
# weighted avg       0.97      0.97      0.97      3278

# %%
model.save_pretrained("./camel_binary_model")
tokenizer.save_pretrained("./camel_binary_model")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ('./camel_binary_model/tokenizer_config.json',
#  './camel_binary_model/tokenizer.json')
